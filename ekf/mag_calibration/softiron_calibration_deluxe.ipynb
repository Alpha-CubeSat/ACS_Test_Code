# %%
'''
Calculating dataset of softiron values for the breadboard IMU
 '''

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

'''
Load and process the data
 '''

# Load the data
path = "/Users/haonan/OneDrive - Cornell University/research/ssds/acs_test_code/data/take3/"

softirons = []

plt.figure(figsize=(6,4), dpi=200)
for i in np.arange(3.6, 4.2, .1): 
  print(i)
  data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])

  pwm = data['PWM']
  mx = data['mag_x']
  my = data['mag_y']
  mz = data['mag_z']

  # Finding the pwm_index of when PWM is 0, but since this dataset specifically only has values for when PWM is -5 and 5, we are going to average it
  zero_pwm_index  = pwm[pwm == -5].index.tolist()[0]

  # mag readings when pwm==0
  mx_offset = (mx[zero_pwm_index] + mx[zero_pwm_index+1])/2
  my_offset = (my[zero_pwm_index] + my[zero_pwm_index+1])/2
  mz_offset = (mz[zero_pwm_index] + mz[zero_pwm_index+1])/2

  start = 0
  end = len(data)

  coeffs_mx = np.polyfit(pwm[start:end], mx[start:end]-mx_offset, 3)
  coeffs_my = np.polyfit(pwm[start:end], my[start:end]-my_offset, 3)
  coeffs_mz = np.polyfit(pwm[start:end], mz[start:end]-mz_offset, 3)

  softiron = [coeffs_mx[2], coeffs_mx[1], coeffs_mx[0], coeffs_my[2], coeffs_my[1], coeffs_my[0], coeffs_mz[2], coeffs_mz[1], coeffs_mz[0]]
  softirons.append(softiron)

# softirons = pd.DataFrame(softirons, columns=['3.6v', '3.7v', '3.8v', '3.9v', '4.0v', '4.1v', '4.2v'])
softirons = pd.DataFrame(softirons).T.rename(columns={0:'3.6v', 1:'3.7v', 2:'3.8v', 3:'3.9v', 4:'4.0v', 5:'4.1v', 6:'4.2v'})
softirons.to_csv('softironcoefs_newboard.csv')
softirons
# Out:
# 3.6
# 3.7
# 3.8000000000000003
# 3.9000000000000004
# 4.0
# 4.1000000000000005
# 4.200000000000001
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_4636/2567988859.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   data = pd.read_csv(path+str(round(i,2))+'v_test.txt', header=1, index_col = False, names=['PWM', 'mag_x', 'mag_y', 'mag_z', 'voltage'])
#            3.6v          3.7v          3.8v          3.9v          4.0v  \
# 0  1.946202e-02  2.375629e-02  2.109250e-02  2.232786e-02  2.436095e-02
# 1 -1.054036e-07 -5.759313e-07  6.463930e-06  7.939150e-06 -4.721884e-06
# 2  2.195769e-08 -6.494126e-09  4.684932e-08 -1.729902e-08 -1.363497e-08
# 3 -3.319764e-03 -2.081774e-03  2.149873e-03 -1.831145e-03 -3.801073e-03
# 4 -8.191978e-07 -2.121123e-06 -1.190205e-05  1.396661e-05 -1.872618e-06
# 5  4.548839e-08  4.233320e-08  1.095423e-11 -1.151997e-08  5.489864e-08
# 6 -1.161318e-01 -1.154974e-01 -1.245036e-01 -1.231885e-01 -1.238004e-01
# 7  4.626960e-06  1.907230e-07 -6.930610e-06 -1.268944e-05  8.112095e-06
# 8  1.040327e-07  3.897409e-09  1.361830e-07  3.939686e-08  3.884068e-08
#
#            4.1v          4.2v
# 0  1.836786e-02  2.430689e-02
# 1 -1.479055e-06 -6.484459e-06
# 2  7.369282e-08 -3.310586e-09
# 3 -4.570206e-03  7.214641e-05
# 4 -2.744473e-06 -2.708878e-06
# 5  4.774451e-08 -2.243396e-08
# 6 -1.237787e-01 -1.315659e-01
# 7 -5.423587e-06  2.643481e-06
# 8  2.151373e-08  4.676025e-08

# %%
''' 
Calculating dataset of softiron values for the cubesat IMU
'''

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

'''
Load and process the data
 '''

# Load the data
path = "/Users/haonan/OneDrive - Cornell University/research/ssds/acs_test_code/data/01.28.2025_voltimu_dataset/"

softirons = []


plt.figure(figsize=(6,4), dpi=200)
for i in np.arange(3.6, 4.2, .1): 
  print(i)
  data = pd.read_csv(path+'cubesat_ztorq_'+str(round(i,2))+'v.txt', names=['values'])

  pwm = []
  mx = []
  my = []
  mz = []

  for i in range(0,len(data), 6):
    pwm.append(float(data.loc[i+1]))
    mx.append(float(data.loc[i+2]))
    my.append(float(data.loc[i+3]))
    mz.append(float(data.loc[i+4]))

  pwm = pd.Series(pwm)
  mx = pd.Series(mx)
  my = pd.Series(my)
  mz = pd.Series(mz)

  # Finding the pwm_index of when PWM is 0, but since this dataset specifically only has values for when PWM is -5 and 5, we are going to average it
  zero_pwm_index  = pwm[pwm == -5].index.tolist()[0]

  # mag readings when pwm==0
  mx_offset = (mx[zero_pwm_index] + mx[zero_pwm_index+1])/2
  my_offset = (my[zero_pwm_index] + my[zero_pwm_index+1])/2
  mz_offset = (mz[zero_pwm_index] + mz[zero_pwm_index+1])/2

  start = 0
  end = len(data)

  coeffs_mx = np.polyfit(pwm[start:end], mx[start:end]-mx_offset, 3)
  coeffs_my = np.polyfit(pwm[start:end], my[start:end]-my_offset, 3)
  coeffs_mz = np.polyfit(pwm[start:end], mz[start:end]-mz_offset, 3)

  softiron = [coeffs_mx[2], coeffs_mx[1], coeffs_mx[0], coeffs_my[2], coeffs_my[1], coeffs_my[0], coeffs_mz[2], coeffs_mz[1], coeffs_mz[0]]
  softirons.append(softiron)

# softirons = pd.DataFrame(softirons, columns=['3.6v', '3.7v', '3.8v', '3.9v', '4.0v', '4.1v', '4.2v'])
softirons = pd.DataFrame(softirons).T.rename(columns={0:'3.6v', 1:'3.7v', 2:'3.8v', 3:'3.9v', 4:'4.0v', 5:'4.1v', 6:'4.2v'})
softirons.to_csv('softirons_z.csv')
softirons
# Out:
# 3.6
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 3.7
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 3.8000000000000003
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 3.9000000000000004
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 4.0
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 4.1000000000000005
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# 4.200000000000001
# pwm: 0    -255.0
# 1    -245.0
# 2    -235.0
# 3    -225.0
# 4    -215.0
# 5    -205.0
# 6    -195.0
# 7    -185.0
# 8    -175.0
# 9    -165.0
# 10   -155.0
# 11   -145.0
# 12   -135.0
# 13   -125.0
# 14   -115.0
# 15   -105.0
# 16    -95.0
# 17    -85.0
# 18    -75.0
# 19    -65.0
# 20    -55.0
# 21    -45.0
# 22    -35.0
# 23    -25.0
# 24    -15.0
# 25     -5.0
# 26      5.0
# 27     15.0
# 28     25.0
# 29     35.0
# 30     45.0
# 31     55.0
# 32     65.0
# 33     75.0
# 34     85.0
# 35     95.0
# 36    105.0
# 37    115.0
# 38    125.0
# 39    135.0
# 40    145.0
# 41    155.0
# 42    165.0
# 43    175.0
# 44    185.0
# 45    195.0
# 46    205.0
# 47    215.0
# 48    225.0
# 49    235.0
# 50    245.0
# 51    255.0
# dtype: float64
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   pwm.append(float(data.loc[i+1]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mx.append(float(data.loc[i+2]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:33: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   my.append(float(data.loc[i+3]))
# /var/folders/w_/5p7jcd6s6qq70g019q88r1mr0000gn/T/ipykernel_2038/659857565.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   mz.append(float(data.loc[i+4]))
